# %%
import pandas as pd

# %%
def read_data():
    df = pd.read_excel(io='Cashbook 2023-2024.xlsx', sheet_name='Journal')

    return df
df= read_data()

# %%
def clean_data(df):
     df = df.fillna(value=0)
     df = df.iloc[:-1]

     return df
clean_data(df)
# Out:
#         ID        Date                                    Description  \
# 0    858.0  06/03/2024                           B&M 022 - WEDNESBURY
# 1    857.0  04/03/2024                                   AMZNMktplace
# 2    855.0  29/02/2024                               ASDA STORES 5130
# 3    854.0  29/02/2024                               ASDA STORES 5130
# 4    853.0  28/02/2024                                  VODAFONE MOTO
# ..     ...         ...                                            ...
# 674  324.0  05/04/2023  TMG                   \tIUM58WPQLTII1ZF0RD DD
# 675  323.0  03/04/2023  GC C1                 \t1STSEDGLEY-CS9BFY9 BG
# 676  323.0  03/04/2023  GC C1                 \t1STSEDGLEY-CS9BFY9 BG
# 677  249.0  03/04/2023     1ST SEDGLEY SCOUT     \tLEGOLAND COACH BBP
# 678  466.0  01/04/2023                                     Xmas Cheer
#
#        Bank Account Name     Cardholder           Category  \
# 0        Expense Account  Robert Barlow    Meetings - Cubs
# ...
